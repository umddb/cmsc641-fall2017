# %%
import pandas as pd
import numpy as np

# %%
req

# %%
sum(requests['Cabin'].isnull())
# Out:
# 687

# %%
meanAge = np.mean(requests.Age)

# %%
meanAge
# Out:
# 29.69911764705882

# %%
requests['Cabin'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
# 5       True
# 6      False
# 7       True
# 8       True
# 9       True
# 10     False
# 11     False
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21     False
# 22      True
# 23     False
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 861     True
# 862    False
# 863     True
# 864     True
# 865     True
# 866     True
# 867    False
# 868     True
# 869     True
# 870     True
# 871    False
# 872    False
# 873     True
# 874     True
# 875     True
# 876     True
# 877     True
# 878     True
# 879    False
# 880     True
# 881     True
# 882     True
# 883     True
# 884     True
# 885     True
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, dtype: bool

# %%
requests
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
np.mean(requests['Fare'])
# Out:
# 32.204207968574636

# %%
np.std(requests['Fare'])
# Out:
# 49.665534444774103

# %%
requests['Fare'].mean()
# Out:
# 32.204207968574636

# %%
requests['Fare'].min()
# Out:
# 0.0

# %%
np.std([1, 2, 3, 4, 5, 6])
# Out:
# 1.707825127659933

# %%
requests.hist(column = 'Fare')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f88271ace80>]], dtype=object)

# %%
# %matplotlib inline

# %%
requests.hist(column = 'Fare')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8825c1e6a0>]], dtype=object)

# %%
requests.sort_values('Fare', ascending=False).head(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259         1       1
# 737          738         1       1
# 679          680         1       1
# 88            89         1       1
# 27            28         0       1
# 341          342         1       1
# 438          439         0       1
# 311          312         1       1
# 742          743         1       1
# 118          119         0       1
# 299          300         1       1
# 557          558         0       1
# 700          701         1       1
# 380          381         1       1
# 716          717         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 258                                   Ward, Miss. Anna  female  35.0      0
# 737                             Lesurer, Mr. Gustave J    male  35.0      0
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# ...
